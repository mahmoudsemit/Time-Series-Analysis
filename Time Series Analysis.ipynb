# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv(r'C:\Users\DELL\Desktop\sales_data.csv')

# %%
data.head()
# Out:
#    customer_id product  sales_amount sale_date
# 0           62       i    456.779766  1/1/2022
# 1           54       i    383.989552  1/1/2022
# 2           24       h    429.963627  1/1/2022
# 3           26       f    505.379044  1/1/2022
# 4           18       b    450.378943  1/1/2022

# %%
data.shape
# Out:
# (1000, 4)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   customer_id   1000 non-null   int64
#  1   product       1000 non-null   object
#  2   sales_amount  1000 non-null   float64
#  3   sale_date     1000 non-null   object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 31.4+ KB

# %%
print('Date range of sales from ',data.iloc[:1,3],'to ',data.iloc[-1,3])
# Out:
# Date range of sales from  0    1/1/2022
# Name: sale_date, dtype: object to  12/31/2022

# %%
data['date']=pd.to_datetime(data['sale_date'])

# %%
data
# Out:
#      customer_id product  sales_amount   sale_date       date
# 0             62       i    456.779766    1/1/2022 2022-01-01
# 1             54       i    383.989552    1/1/2022 2022-01-01
# 2             24       h    429.963627    1/1/2022 2022-01-01
# 3             26       f    505.379044    1/1/2022 2022-01-01
# 4             18       b    450.378943    1/1/2022 2022-01-01
# ..           ...     ...           ...         ...        ...
# 995            1       c    621.737696  12/30/2022 2022-12-30
# 996           23       a    494.994228  12/30/2022 2022-12-30
# 997           27       h    323.451907  12/31/2022 2022-12-31
# 998           21       e    535.637496  12/31/2022 2022-12-31
# 999           63       d    461.719980  12/31/2022 2022-12-31
#
# [1000 rows x 5 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   customer_id   1000 non-null   int64
#  1   product       1000 non-null   object
#  2   sales_amount  1000 non-null   float64
#  3   sale_date     1000 non-null   object
#  4   date          1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 39.2+ KB

# %%
data.drop('sale_date',axis=1)
# Out:
#      customer_id product  sales_amount       date
# 0             62       i    456.779766 2022-01-01
# 1             54       i    383.989552 2022-01-01
# 2             24       h    429.963627 2022-01-01
# 3             26       f    505.379044 2022-01-01
# 4             18       b    450.378943 2022-01-01
# ..           ...     ...           ...        ...
# 995            1       c    621.737696 2022-12-30
# 996           23       a    494.994228 2022-12-30
# 997           27       h    323.451907 2022-12-31
# 998           21       e    535.637496 2022-12-31
# 999           63       d    461.719980 2022-12-31
#
# [1000 rows x 4 columns]

# %%
data=data.set_index('date')

# %%
data[['sales_amount']].plot(figsize=(10,7))
plt.title('Sales Amount in 2022')
plt.xlabel('Year of 2022')
plt.ylabel('Sales Amount')
plt.grid()

# %%
data[['sales_amount']].rolling(15).mean().plot(figsize=(10,7))
# Out:
# <Axes: xlabel='date'>

# %%
_,ax=plt.subplots(figsize=(10,7))
sns.boxplot(x=data.index.month, y=data.sales_amount)
# Out:
# <Axes: xlabel='date', ylabel='sales_amount'>
